# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline 
import seaborn as sns

# %%
dfBitcoin = pd.read_csv("bitcoin_historical_data.csv")
dfBitcoin
# Out:
#           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980       NaN       NaN       NaN       NaN           NaN
# 2        1325318040       NaN       NaN       NaN       NaN           NaN
# 3        1325318100       NaN       NaN       NaN       NaN           NaN
# 4        1325318160       NaN       NaN       NaN       NaN           NaN
# ...             ...       ...       ...       ...       ...           ...
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
# First, we have to drop all of the rows with missing values so we could calculate Q1, Q3, and IQR
# Otherwise, Q1, Q3, and IQR calculation would just show up as nan
dfBitcoin = dfBitcoin.dropna(subset=['Open'])

# Calculate the minimum value, the maximum value, the mean, the standard deviation, Q1, median, Q3, and the IQR of Open Price
minValueOpen = dfBitcoin['Open'].min()
maxValueOpen = dfBitcoin['Open'].max()
meanOpen = dfBitcoin['Open'].mean()
stdOpen = dfBitcoin['Open'].std()
q1Open = np.percentile(dfBitcoin['Open'], 25)
medianOpen = dfBitcoin['Open'].median()
q3Open = np.percentile(dfBitcoin['Open'], 75)
IQROpen = q3Open - q1Open

print("The minimum value for Open price is " + str(minValueOpen))
print("The maximum value for Open price is " + str(maxValueOpen))
print("The mean for Open price is " + str(meanOpen))
print("The standard deviation for Open price is " + str(stdOpen))
print("Q1 for Open price is " + str(q1Open))
print("The median for Open price is " + str(medianOpen))
print("Q3 for Open price is " + str(q3Open))
print("IQR for Open price is " + str(IQROpen))
# Out:
# The minimum value for Open price is 3.8
# The maximum value for Open price is 61763.56
# The mean for Open price is 6009.023680137011
# The standard deviation for Open price is 8996.24735115404
# Q1 for Open price is 443.86
# The median for Open price is 3596.97
# Q3 for Open price is 8627.27
# IQR for Open price is 8183.410000000001

# %%
# First, we have to drop all of the rows with missing values so we could calculate Q1, Q3, and IQR
# Otherwise, Q1, Q3, and IQR calculation would just show up as nan
dfBitcoin = dfBitcoin.dropna(subset=['High'])

# Calculate the minimum value, the maximum value, the mean, the standard deviation, Q1, median, Q3, and the IQR of High Price
minValueHigh = dfBitcoin['High'].min()
maxValueHigh = dfBitcoin['High'].max()
meanHigh = dfBitcoin['High'].mean()
stdHigh = dfBitcoin['High'].std()
q1High = np.percentile(dfBitcoin['High'], 25)
medianHigh = dfBitcoin['High'].median()
q3High = np.percentile(dfBitcoin['High'], 75)
IQRHigh = q3High - q1High

print("The minimum value for High price is " + str(minValueHigh))
print("The maximum value for High price is " + str(maxValueHigh))
print("The mean for High price is " + str(meanHigh))
print("The standard deviation for High price is " + str(stdHigh))
print("Q1 for High price is " + str(q1High))
print("The median for High price is " + str(medianHigh))
print("Q3 for High price is " + str(q3High))
print("IQR for High price is " + str(IQRHigh))
# Out:
# The minimum value for High price is 3.8
# The maximum value for High price is 61781.83
# The mean for High price is 6013.357081609536
# The standard deviation for High price is 9003.521006376617
# Q1 for High price is 444.0
# The median for High price is 3598.19
# Q3 for High price is 8632.98
# IQR for High price is 8188.98

# %%
# First, we have to drop all of the rows with missing values so we could calculate Q1, Q3, and IQR
# Otherwise, Q1, Q3, and IQR calculation would just show up as nan
dfBitcoin = dfBitcoin.dropna(subset=['Low'])

# Calculate the minimum value, the maximum value, the mean, the standard deviation, Q1, median, Q3, and the IQR of Low Price
minValueLow = dfBitcoin['Low'].min()
maxValueLow = dfBitcoin['Low'].max()
meanLow = dfBitcoin['Low'].mean()
stdLow = dfBitcoin['Low'].std()
q1Low = np.percentile(dfBitcoin['Low'], 25)
medianLow = dfBitcoin['Low'].median()
q3Low = np.percentile(dfBitcoin['Low'], 75)
IQRLow = q3Low - q1Low

print("The minimum value for Low price is " + str(minValueLow))
print("The maximum value for Low price is " + str(maxValueLow))
print("The mean for Low price is " + str(meanLow))
print("The standard deviation for Low price is " + str(stdLow))
print("Q1 for Low price is " + str(q1Low))
print("The median for Low price is " + str(medianLow))
print("Q3 for Low price is " + str(q3Low))
print("IQR for Low price is " + str(IQRLow))
# Out:
# The minimum value for Low price is 1.5
# The maximum value for Low price is 61673.55
# The mean for Low price is 6004.4880035062515
# The standard deviation for Low price is 8988.778318952896
# Q1 for Low price is 443.52
# The median for Low price is 3595.62
# Q3 for Low price is 8621.09
# IQR for Low price is 8177.57

# %%
# First, we have to drop all of the rows with missing values so we could calculate Q1, Q3, and IQR
# Otherwise, Q1, Q3, and IQR calculation would just show up as nan
dfBitcoin = dfBitcoin.dropna(subset=['Close'])

# Calculate the minimum value, the maximum value, the mean, the standard deviation, Q1, median, Q3, and the IQR of Close Price
minValueClose = dfBitcoin['Close'].min()
maxValueClose = dfBitcoin['Close'].max()
meanClose = dfBitcoin['Close'].mean()
stdClose = dfBitcoin['Close'].std()
q1Close = np.percentile(dfBitcoin['Close'], 25)
medianClose = dfBitcoin['Close'].median()
q3Close = np.percentile(dfBitcoin['Close'], 75)
IQRClose = q3Close - q1Close

print("The minimum value for Close price is " + str(minValueClose))
print("The maximum value for Close price is " + str(maxValueClose))
print("The mean for Close price is " + str(meanClose))
print("The standard deviation for Close price is " + str(stdClose))
print("Q1 for Close price is " + str(q1Close))
print("The median for Close price is " + str(medianClose))
print("Q3 for Close price is " + str(q3Close))
print("IQR for Close price is " + str(IQRClose))
# Out:
# The minimum value for Close price is 1.5
# The maximum value for Close price is 61781.8
# The mean for Close price is 6009.013545015653
# The standard deviation for Close price is 8996.359688354543
# Q1 for Close price is 443.86
# The median for Close price is 3597.0
# Q3 for Close price is 8627.16
# IQR for Close price is 8183.3

# %%
# First, we have to drop all of the rows with missing values so we could calculate Q1, Q3, and IQR
# Otherwise, Q1, Q3, and IQR calculation would just show up as nan
dfBitcoin = dfBitcoin.dropna(subset=['Volume_(BTC)'])

# Calculate the minimum value, the maximum value, the mean, the standard deviation, Q1, median, Q3, and the IQR of Volume (BTC)
minValueVolumeBTC = dfBitcoin['Volume_(BTC)'].min()
maxValueVolumeBTC = dfBitcoin['Volume_(BTC)'].max()
meanVolumeBTC = dfBitcoin['Volume_(BTC)'].mean()
stdVolumeBTC = dfBitcoin['Volume_(BTC)'].std()
q1VolumeBTC = np.percentile(dfBitcoin['Volume_(BTC)'], 25)
medianVolumeBTC = dfBitcoin['Volume_(BTC)'].median()
q3VolumeBTC = np.percentile(dfBitcoin['Volume_(BTC)'], 75)
IQRVolumeBTC = q3VolumeBTC - q1VolumeBTC

print("The minimum value for Volume (BTC) is " + str(minValueVolumeBTC))
print("The maximum value for Volume (BTC) is " + str(maxValueVolumeBTC))
print("The mean for Volume (BTC) is " + str(meanVolumeBTC))
print("The standard deviation for Volume (BTC) is " + str(stdVolumeBTC))
print("Q1 for Volume (BTC) is " + str(q1VolumeBTC))
print("The median for Volume (BTC) is " + str(medianVolumeBTC))
print("Q3 for Volume (BTC) is " + str(q3VolumeBTC))
print("IQR for Volume (BTC) is " + str(IQRVolumeBTC))
# Out:
# The minimum value for Volume (BTC) is 0.0
# The maximum value for Volume (BTC) is 5853.8521659
# The mean for Volume (BTC) is 9.323249222687261
# The standard deviation for Volume (BTC) is 30.549891244121838
# Q1 for Volume (BTC) is 0.40977594
# The median for Volume (BTC) is 1.97981073
# Q3 for Volume (BTC) is 7.27821636
# IQR for Volume (BTC) is 6.86844042

# %%
# First, we have to drop all of the rows with missing values so we could calculate Q1, Q3, and IQR
# Otherwise, Q1, Q3, and IQR calculation would just show up as nan
dfBitcoin = dfBitcoin.dropna(subset=['Volume_(Currency)'])

# Calculate the minimum value, the maximum value, the mean, the standard deviation, Q1, median, Q3, and the IQR of Volume (Currency)
minValueVolumeCurrency = dfBitcoin['Volume_(Currency)'].min()
maxValueVolumeCurrency = dfBitcoin['Volume_(Currency)'].max()
meanVolumeCurrency = dfBitcoin['Volume_(Currency)'].mean()
stdVolumeCurrency = dfBitcoin['Volume_(Currency)'].std()
q1VolumeCurrency = np.percentile(dfBitcoin['Volume_(Currency)'], 25)
medianVolumeCurrency = dfBitcoin['Volume_(Currency)'].median()
q3VolumeCurrency = np.percentile(dfBitcoin['Volume_(Currency)'], 75)
IQRVolumeCurrency = q3VolumeCurrency - q1VolumeCurrency

print("The minimum value for Volume (Currency) is " + str(minValueVolumeCurrency))
print("The maximum value for Volume (Currency) is " + str(maxValueVolumeCurrency))
print("The mean for Volume (Currency) is " + str(meanVolumeCurrency))
print("The standard deviation for Volume (Currency) is " + str(stdVolumeCurrency))
print("Q1 for Volume (Currency) is " + str(q1VolumeCurrency))
print("The median for Volume (Currency) is " + str(medianVolumeCurrency))
print("Q3 for Volume (Currency) is " + str(q3VolumeCurrency))
print("IQR for Volume (Currency) is " + str(IQRVolumeCurrency))
# Out:
# The minimum value for Volume (Currency) is 0.0
# The maximum value for Volume (Currency) is 13900672.407
# The mean for Volume (Currency) is 41762.842397077846
# The standard deviation for Volume (Currency) is 151824.78390068075
# Q1 for Volume (Currency) is 452.14219543
# The median for Volume (Currency) is 3810.1241431
# Q3 for Volume (Currency) is 25698.211176
# IQR for Volume (Currency) is 25246.068980570002

# %%
# First, we have to drop all of the rows with missing values so we could calculate Q1, Q3, and IQR
# Otherwise, Q1, Q3, and IQR calculation would just show up as nan
dfBitcoin = dfBitcoin.dropna(subset=['Weighted_Price'])

# Calculate the minimum value, the maximum value, the mean, the standard deviation, Q1, median, Q3, and the IQR of Weighted Price
minValueWeightedPrice = dfBitcoin['Weighted_Price'].min()
maxValueWeightedPrice = dfBitcoin['Weighted_Price'].max()
meanWeightedPrice = dfBitcoin['Weighted_Price'].mean()
stdWeightedPrice = dfBitcoin['Weighted_Price'].std()
q1WeightedPrice = np.percentile(dfBitcoin['Weighted_Price'], 25)
medianWeightedPrice = dfBitcoin['Weighted_Price'].median()
q3WeightedPrice = np.percentile(dfBitcoin['Weighted_Price'], 75)
IQRWeightedPrice = q3WeightedPrice - q1WeightedPrice

print("The minimum value for Weighted price is " + str(minValueWeightedPrice))
print("The maximum value for Weighted price is " + str(maxValueWeightedPrice))
print("The mean for Weighted price is " + str(meanWeightedPrice))
print("The standard deviation for Weighted price is " + str(stdWeightedPrice))
print("Q1 for Volume Weighted price is " + str(q1WeightedPrice))
print("The median for Weighted price is " + str(medianWeightedPrice))
print("Q3 for Volume Weighted price is " + str(q3WeightedPrice))
print("IQR for Volume Weighted price is " + str(IQRWeightedPrice))
# Out:
# The minimum value for Weighted price is 3.8
# The maximum value for Weighted price is 61716.205341
# The mean for Weighted price is 6008.9348002888655
# The standard deviation for Weighted price is 8995.99164341298
# Q1 for Volume Weighted price is 443.83062155
# The median for Weighted price is 3596.8041447
# Q3 for Volume Weighted price is 8627.6366135
# IQR for Volume Weighted price is 8183.805991950001

# %%
# We convert the timestamp column of the dataset to actual human readable timestamp
# As we can see, it is from 2012 to 2021
dfBitcoin['Timestamp'] = pd.to_datetime(dfBitcoin['Timestamp'], unit='s')
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Open'], label='Open Price')
plt.title('Bitcoin Open Price Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Open Price (USD)')
plt.legend()
plt.show()

# %%
# Graph for High Price Over Time
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['High'], label='High Price')
plt.title('Bitcoin High Price Over Time')
plt.xlabel('Timestamp')
plt.ylabel('High Price (USD)')
plt.legend()
plt.show()

# %%
# Graph for Low Price Over Time
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Low'], label='Low Price')
plt.title('Bitcoin Low Price Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Low Price (USD)')
plt.legend()
plt.show()

# %%
# Graph for Close Price Over Time
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Close'], label='Close Price')
plt.title('Bitcoin Close Price Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.show()

# %%
# Graph for Bitcoin Volume (BTC) Over Time
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Volume_(BTC)'], label='Volume (BTC)')
plt.title('Bitcoin Volume (BTC) Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Volume (BTC)')
plt.legend()
plt.show()

# %%
# Graph for Bitcoin Volume (Currency) Over Time
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Volume_(Currency)'], label='Volume (Currency)')
plt.title('Bitcoin Volume (Currency) Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Volume (Currency)')
plt.legend()
plt.show()

# %%
# Graph for Weighted Price Over Time
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Weighted_Price'], label='Weighted Price')
plt.title('Bitcoin Weighted Price Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Weighted Price')
plt.legend()
plt.show()

# %%
# This graph is to calculate the percentage change of the value of the bitcoin prices from one day to another
dfBitcoin['Daily_Return_Open'] = dfBitcoin['Open'].pct_change()
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Daily_Return_Open'], label='Daily Returns Open Price')
plt.title('Bitcoin Open Price Daily Returns Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Daily Returns Open Price')
plt.legend()
plt.show()

# %%
dfBitcoin['Daily_Return_High'] = dfBitcoin['High'].pct_change()
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Daily_Return_High'], label='Daily Returns High Price')
plt.title('Bitcoin High Price Daily Returns Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Daily Returns High Price')
plt.legend()
plt.show()

# %%
dfBitcoin['Daily_Return_Low'] = dfBitcoin['Low'].pct_change()
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Daily_Return_Low'], label='Daily Returns Low Price}')
plt.title('Bitcoin Low Price Daily Returns Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Daily Returns Low Price')
plt.legend()
plt.show()

# %%
dfBitcoin['Daily_Return_Close'] = dfBitcoin['Close'].pct_change()
plt.figure(figsize=(10, 8))
plt.plot(dfBitcoin['Timestamp'], dfBitcoin['Daily_Return_Close'], label='Daily Returns Close Price')
plt.title('Bitcoin Close Price Daily Returns Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Daily Returns Close Price')
plt.legend()
plt.show()

# %%
# Below is the heat map of the correlations between each variable in the dataset
correlation_matrix = dfBitcoin[['Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(Currency)', 'Weighted_Price']].corr()
plt.figure(figsize=(10, 8))

# Hide the top part of the map
mask = np.triu(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', mask=mask)
plt.title('The heat map of the correlations between each variable in the dataset')
plt.show()

# %% [markdown]
# As we can see throughout the closely inspection of each columns and what they do, there is a relationship between Open and High, and between Low and Close. Also, the plot graph for those 4 are very similar to one another, which indicates that there is only a small difference between each variable of Open Price, High Price, Low Price, and Close Price. Meanwhile, the Volume (BTC) and the Volume (Currency) has an opposite relationship. As we can see with the plot graph above, the Volume (BTC) is peaking on the right side of the graph and the Volume (Currency) is peaking on the left side of the graph. I also inlcuded a heat map betweeen each variable in the dataset above so that we can easily see the correlations between each variables.
